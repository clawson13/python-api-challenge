# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.
#
# #### Analyis
# Observed Trends
# 1.
# 2.
# 3.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 640

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# set up lists to hold reponse info
city_final = []
lat = []
long = []
maxtemp = []
humidity = []
cloudiness = []
wind = []
country = []
date = []

# Set variables for city numbers/Set counts
record = 0
recordset = 1

# Display header for the print log
print("Beginning Data Retrieval")
print("-----------------------------")

# Loop through the list of cities and perform a request for data on each
for city in cities:
    
    try:
        response = requests.get(query_url + city).json()
        
        # Add to city count
        record += 1

        # Print city to log
        print(f"Processing Record {record} of Set {recordset} | {city}")
        
        # Append city's data to lists
        city_final.append(response['name'])
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])    
        maxtemp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])    
        cloudiness.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])    
        country.append(response['sys']['country'])
        date.append(response['sys']['sunrise'])
        
        # Reset the city count at 50 and step Set number
        if record >= 50:
            record = 0
            recordset += 1
            
    except (KeyError, IndexError):
        # Add to city count
        record += 1        
        # Reset the city count at 50 and step Set number
        if record >= 50:
            record = 0
            recordset += 1
        print("City not found. Skipping...")

# Display footer for the print log
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | cervo
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | tuatapere
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | novoorsk
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 1 | saldanha
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 1 | cayenne
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | gizo
# Processing Record 19 of Set 1 | carballo
# Processing Record 20 of Set 1 | kodiak
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | moranbah
# Processing Record 24 of Set 1 | arraial do cabo
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | paraiso
# Processing Record 30 of Set 1 | sao filipe
# Processing Record 31 of Set 1 | katsuura
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | faanui
# Processing Record 34 of Set 1 | esperance
# Processing Record 35 of Set 1 | kochkurovo
# Processing Record 36 of Set 1 | praia da vitoria
# Processing Record 37 of Set 1 | kiunga
# Processing Record 38 of Set 1 | bluefields
# Processing Record 39 of Set 1 | bambous virieux
# Processing Record 40 of Set 1 | abu samrah
# Processing Record 41 of Set 1 | saint-pierre
# Processing Record 42 of Set 1 | chateauroux
# Processing Record 43 of Set 1 | narsaq
# Processing Record 44 of Set 1 | lomovka
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | husavik
# Processing Record 50 of Set 1 | khombole
# Processing Record 1 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 2 | shawville
# Processing Record 4 of Set 2 | naze
# Processing Record 5 of Set 2 | torbay
# Processing Record 6 of Set 2 | nouadhibou
# Processing Record 7 of Set 2 | bulungu
# Processing Record 8 of Set 2 | tasiilaq
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | vila velha
# Processing Record 11 of Set 2 | college
# Processing Record 12 of Set 2 | chokurdakh
# Processing Record 13 of Set 2 | manakara
# Processing Record 14 of Set 2 | kaitangata
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | tual
# Processing Record 17 of Set 2 | karamken
# City not found. Skipping...
# Processing Record 19 of Set 2 | geraldton
# Processing Record 20 of Set 2 | vostok
# Processing Record 21 of Set 2 | mahebourg
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 2 | hasaki
# Processing Record 26 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | bathsheba
# Processing Record 30 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 32 of Set 2 | saravan
# Processing Record 33 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 2 | coahuayana
# Processing Record 36 of Set 2 | piracaia
# Processing Record 37 of Set 2 | lorengau
# Processing Record 38 of Set 2 | iberia
# Processing Record 39 of Set 2 | ostrovnoy
# Processing Record 40 of Set 2 | lagoa
# Processing Record 41 of Set 2 | xinzhou
# Processing Record 42 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 44 of Set 2 | port alfred
# Processing Record 45 of Set 2 | mogadishu
# Processing Record 46 of Set 2 | road town
# Processing Record 47 of Set 2 | ixtapa
# Processing Record 48 of Set 2 | moerai
# Processing Record 49 of Set 2 | bairnsdale
# Processing Record 50 of Set 2 | bredasdorp
# Processing Record 1 of Set 3 | morant bay
# Processing Record 2 of Set 3 | termini imerese
# Processing Record 3 of Set 3 | iracoubo
# Processing Record 4 of Set 3 | anadyr
# Processing Record 5 of Set 3 | victoria
# Processing Record 6 of Set 3 | abrau-dyurso
# Processing Record 7 of Set 3 | tautira
# Processing Record 8 of Set 3 | puerto leguizamo
# Processing Record 9 of Set 3 | cabo san lucas
# Processing Record 10 of Set 3 | butaritari
# Processing Record 11 of Set 3 | ust-ilimsk
# Processing Record 12 of Set 3 | puerto ayora
# Processing Record 13 of Set 3 | fairfax
# Processing Record 14 of Set 3 | mezen
# Processing Record 15 of Set 3 | norman wells
# Processing Record 16 of Set 3 | bambanglipuro
# Processing Record 17 of Set 3 | fortuna
# Processing Record 18 of Set 3 | lavrentiya
# Processing Record 19 of Set 3 | port lincoln
# Processing Record 20 of Set 3 | grenada
# Processing Record 21 of Set 3 | kavaratti
# Processing Record 22 of Set 3 | lethbridge
# Processing Record 23 of Set 3 | ormara
# Processing Record 24 of Set 3 | bengkulu
# Processing Record 25 of Set 3 | qaqortoq
# Processing Record 26 of Set 3 | xai-xai
# Processing Record 27 of Set 3 | marienburg
# Processing Record 28 of Set 3 | ribeira grande
# Processing Record 29 of Set 3 | upernavik
# Processing Record 30 of Set 3 | miles city
# Processing Record 31 of Set 3 | hithadhoo
# Processing Record 32 of Set 3 | progreso
# Processing Record 33 of Set 3 | portland
# Processing Record 34 of Set 3 | new norfolk
# Processing Record 35 of Set 3 | buala
# Processing Record 36 of Set 3 | saryagash
# Processing Record 37 of Set 3 | chuy
# Processing Record 38 of Set 3 | bacuit
# City not found. Skipping...
# Processing Record 40 of Set 3 | thompson
# Processing Record 41 of Set 3 | pyshchug
# Processing Record 42 of Set 3 | kamaishi
# Processing Record 43 of Set 3 | taihe
# Processing Record 44 of Set 3 | casa nova
# Processing Record 45 of Set 3 | nanortalik
# Processing Record 46 of Set 3 | kaseda
# Processing Record 47 of Set 3 | ahome
# Processing Record 48 of Set 3 | chkalovskoye
# Processing Record 49 of Set 3 | leningradskiy
# Processing Record 50 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 4 | santa maria
# Processing Record 2 of Set 4 | penjamo
# Processing Record 3 of Set 4 | flinders
# Processing Record 4 of Set 4 | mar del plata
# Processing Record 5 of Set 4 | tiksi
# Processing Record 6 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 8 of Set 4 | half moon bay
# Processing Record 9 of Set 4 | srednekolymsk
# Processing Record 10 of Set 4 | los llanos de aridane
# Processing Record 11 of Set 4 | ketchikan
# Processing Record 12 of Set 4 | khandyga
# Processing Record 13 of Set 4 | solnechnyy
# Processing Record 14 of Set 4 | cidreira
# Processing Record 15 of Set 4 | hobart
# Processing Record 16 of Set 4 | nikolskoye
# Processing Record 17 of Set 4 | codrington
# Processing Record 18 of Set 4 | baruun-urt
# Processing Record 19 of Set 4 | julio de castilhos
# Processing Record 20 of Set 4 | jiaojiang
# Processing Record 21 of Set 4 | beringovskiy
# Processing Record 22 of Set 4 | formosa do rio preto
# Processing Record 23 of Set 4 | khasan
# Processing Record 24 of Set 4 | dikson
# Processing Record 25 of Set 4 | nurota
# Processing Record 26 of Set 4 | puerto escondido
# Processing Record 27 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 29 of Set 4 | scottsbluff
# Processing Record 30 of Set 4 | dingle
# Processing Record 31 of Set 4 | takapau
# Processing Record 32 of Set 4 | provideniya
# Processing Record 33 of Set 4 | broome
# Processing Record 34 of Set 4 | tomatlan
# Processing Record 35 of Set 4 | sulangan
# Processing Record 36 of Set 4 | galle
# Processing Record 37 of Set 4 | shkoder
# Processing Record 38 of Set 4 | santa rosa
# Processing Record 39 of Set 4 | mogzon
# Processing Record 40 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 4 | airai
# Processing Record 43 of Set 4 | erice
# Processing Record 44 of Set 4 | long xuyen
# Processing Record 45 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 4 | porto novo
# Processing Record 48 of Set 4 | calabozo
# Processing Record 49 of Set 4 | kijang
# Processing Record 50 of Set 4 | atasu
# Processing Record 1 of Set 5 | georgetown
# Processing Record 2 of Set 5 | savonlinna
# Processing Record 3 of Set 5 | mecca
# Processing Record 4 of Set 5 | carnarvon
# Processing Record 5 of Set 5 | souillac
# Processing Record 6 of Set 5 | mishkino
# Processing Record 7 of Set 5 | cherskiy
# Processing Record 8 of Set 5 | severo-kurilsk
# Processing Record 9 of Set 5 | klaksvik
# Processing Record 10 of Set 5 | ulaanbaatar
# Processing Record 11 of Set 5 | valparaiso
# Processing Record 12 of Set 5 | celestun
# Processing Record 13 of Set 5 | bereda
# Processing Record 14 of Set 5 | clyde river
# Processing Record 15 of Set 5 | ribera
# Processing Record 16 of Set 5 | ponta do sol
# Processing Record 17 of Set 5 | bethel
# Processing Record 18 of Set 5 | vila franca do campo
# Processing Record 19 of Set 5 | strezhevoy
# Processing Record 20 of Set 5 | najran
# Processing Record 21 of Set 5 | rawlins
# Processing Record 22 of Set 5 | canmore
# Processing Record 23 of Set 5 | vardo
# Processing Record 24 of Set 5 | marzuq
# Processing Record 25 of Set 5 | praya
# Processing Record 26 of Set 5 | saint-philippe
# Processing Record 27 of Set 5 | lensk
# Processing Record 28 of Set 5 | woodstock
# Processing Record 29 of Set 5 | plettenberg bay
# Processing Record 30 of Set 5 | juegang
# Processing Record 31 of Set 5 | saint george
# Processing Record 32 of Set 5 | olafsvik
# Processing Record 33 of Set 5 | tsumeb
# Processing Record 34 of Set 5 | manokwari
# Processing Record 35 of Set 5 | tahe
# Processing Record 36 of Set 5 | baboua
# City not found. Skipping...
# Processing Record 38 of Set 5 | xingyi
# Processing Record 39 of Set 5 | cap malheureux
# Processing Record 40 of Set 5 | saint-augustin
# Processing Record 41 of Set 5 | saltabarranca
# Processing Record 42 of Set 5 | san quintin
# Processing Record 43 of Set 5 | port blair
# Processing Record 44 of Set 5 | lahaina
# Processing Record 45 of Set 5 | vestmanna
# Processing Record 46 of Set 5 | alofi
# Processing Record 47 of Set 5 | ahuimanu
# Processing Record 48 of Set 5 | ribeira brava
# Processing Record 49 of Set 5 | komsomolskiy
# Processing Record 50 of Set 5 | iralaya
# Processing Record 1 of Set 6 | alamos
# Processing Record 2 of Set 6 | bintulu
# Processing Record 3 of Set 6 | festus
# Processing Record 4 of Set 6 | morondava
# Processing Record 5 of Set 6 | mahon
# Processing Record 6 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 6 | turan
# Processing Record 9 of Set 6 | awbari
# Processing Record 10 of Set 6 | klyuchi
# Processing Record 11 of Set 6 | dubbo
# Processing Record 12 of Set 6 | ekpoma
# Processing Record 13 of Set 6 | pecos
# Processing Record 14 of Set 6 | urubicha
# Processing Record 15 of Set 6 | markova
# Processing Record 16 of Set 6 | ilulissat
# Processing Record 17 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 6 | helong
# Processing Record 20 of Set 6 | tawang
# Processing Record 21 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 23 of Set 6 | luderitz
# Processing Record 24 of Set 6 | kutum
# Processing Record 25 of Set 6 | zhigansk
# Processing Record 26 of Set 6 | yuanli
# Processing Record 27 of Set 6 | nokia
# Processing Record 28 of Set 6 | iskilip
# Processing Record 29 of Set 6 | kisangani
# Processing Record 30 of Set 6 | coquimbo
# Processing Record 31 of Set 6 | qunduz
# Processing Record 32 of Set 6 | filadelfia
# Processing Record 33 of Set 6 | bonnyville
# Processing Record 34 of Set 6 | tazovskiy
# Processing Record 35 of Set 6 | nisia floresta
# Processing Record 36 of Set 6 | kazanovka
# City not found. Skipping...
# Processing Record 38 of Set 6 | haines junction
# Processing Record 39 of Set 6 | bjornevatn
# Processing Record 40 of Set 6 | jackson
# Processing Record 41 of Set 6 | bontang
# Processing Record 42 of Set 6 | aykhal
# Processing Record 43 of Set 6 | burnie
# Processing Record 44 of Set 6 | koutiala
# Processing Record 45 of Set 6 | mount gambier
# Processing Record 46 of Set 6 | kasempa
# Processing Record 47 of Set 6 | balatonszarszo
# Processing Record 48 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 50 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 1 of Set 7 | prince rupert
# Processing Record 2 of Set 7 | vanavara
# Processing Record 3 of Set 7 | pevek
# Processing Record 4 of Set 7 | simbakoro
# Processing Record 5 of Set 7 | vanimo
# Processing Record 6 of Set 7 | novyy urengoy
# Processing Record 7 of Set 7 | lebu
# Processing Record 8 of Set 7 | port-gentil
# Processing Record 9 of Set 7 | phuket
# Processing Record 10 of Set 7 | sovetskiy
# Processing Record 11 of Set 7 | olinda
# Processing Record 12 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 7 | samarai
# Processing Record 15 of Set 7 | hede
# Processing Record 16 of Set 7 | etchoropo
# Processing Record 17 of Set 7 | port elizabeth
# Processing Record 18 of Set 7 | quelimane
# Processing Record 19 of Set 7 | creston
# Processing Record 20 of Set 7 | savannakhet
# Processing Record 21 of Set 7 | the valley
# Processing Record 22 of Set 7 | general pico
# Processing Record 23 of Set 7 | pitimbu
# Processing Record 24 of Set 7 | grand baie
# Processing Record 25 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 7 | estelle
# Processing Record 28 of Set 7 | sassandra
# Processing Record 29 of Set 7 | teknaf
# Processing Record 30 of Set 7 | korem
# Processing Record 31 of Set 7 | minsk
# Processing Record 32 of Set 7 | ambon
# Processing Record 33 of Set 7 | meulaboh
# Processing Record 34 of Set 7 | salmas
# Processing Record 35 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 7 | langsa
# Processing Record 38 of Set 7 | termiz
# Processing Record 39 of Set 7 | varhaug
# Processing Record 40 of Set 7 | khatanga
# Processing Record 41 of Set 7 | korla
# Processing Record 42 of Set 7 | pochutla
# Processing Record 43 of Set 7 | fare
# Processing Record 44 of Set 7 | jaque
# Processing Record 45 of Set 7 | beinamar
# Processing Record 46 of Set 7 | laguna
# Processing Record 47 of Set 7 | salekhard
# Processing Record 48 of Set 7 | mandal
# Processing Record 49 of Set 7 | grand gaube
# Processing Record 50 of Set 7 | fenoarivo
# Processing Record 1 of Set 8 | beyneu
# Processing Record 2 of Set 8 | paamiut
# Processing Record 3 of Set 8 | isangel
# Processing Record 4 of Set 8 | gezing
# Processing Record 5 of Set 8 | pisco
# Processing Record 6 of Set 8 | puerto colombia
# Processing Record 7 of Set 8 | sola
# Processing Record 8 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 10 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 8 | kasungu
# Processing Record 15 of Set 8 | sigli
# Processing Record 16 of Set 8 | karratha
# Processing Record 17 of Set 8 | dologon
# Processing Record 18 of Set 8 | bochnia
# Processing Record 19 of Set 8 | elko
# Processing Record 20 of Set 8 | venice
# Processing Record 21 of Set 8 | aklavik
# Processing Record 22 of Set 8 | jiaozuo
# Processing Record 23 of Set 8 | adrar
# Processing Record 24 of Set 8 | yaan
# Processing Record 25 of Set 8 | khovu-aksy
# Processing Record 26 of Set 8 | kandrian
# Processing Record 27 of Set 8 | jacmel
# Processing Record 28 of Set 8 | pula
# Processing Record 29 of Set 8 | pundaguitan
# Processing Record 30 of Set 8 | matagami
# Processing Record 31 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 33 of Set 8 | san cristobal
# Processing Record 34 of Set 8 | buchanan
# Processing Record 35 of Set 8 | paredon
# Processing Record 36 of Set 8 | nieuw amsterdam
# Processing Record 37 of Set 8 | igrim
# Processing Record 38 of Set 8 | kassala
# Processing Record 39 of Set 8 | eskil
# Processing Record 40 of Set 8 | richards bay
# Processing Record 41 of Set 8 | salalah
# Processing Record 42 of Set 8 | walla walla
# Processing Record 43 of Set 8 | asau
# Processing Record 44 of Set 8 | atar
# Processing Record 45 of Set 8 | ancud
# Processing Record 46 of Set 8 | bremerton
# Processing Record 47 of Set 8 | nishihara
# Processing Record 48 of Set 8 | iglesias
# Processing Record 49 of Set 8 | moose factory
# Processing Record 50 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 9 | dengzhou
# Processing Record 2 of Set 9 | rancho palos verdes
# Processing Record 3 of Set 9 | mehamn
# Processing Record 4 of Set 9 | taloqan
# Processing Record 5 of Set 9 | muros
# Processing Record 6 of Set 9 | avarua
# Processing Record 7 of Set 9 | atami
# Processing Record 8 of Set 9 | nemuro
# Processing Record 9 of Set 9 | vilhena
# Processing Record 10 of Set 9 | auki
# Processing Record 11 of Set 9 | kismayo
# Processing Record 12 of Set 9 | forio
# Processing Record 13 of Set 9 | loei
# Processing Record 14 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 9 | boone
# Processing Record 17 of Set 9 | shestakovo
# Processing Record 18 of Set 9 | caravelas
# Processing Record 19 of Set 9 | katobu
# Processing Record 20 of Set 9 | sur
# Processing Record 21 of Set 9 | cortez
# Processing Record 22 of Set 9 | puerto carreno
# Processing Record 23 of Set 9 | tura
# Processing Record 24 of Set 9 | touros
# Processing Record 25 of Set 9 | homberg
# Processing Record 26 of Set 9 | tarrafal
# Processing Record 27 of Set 9 | salinopolis
# Processing Record 28 of Set 9 | porecatu
# Processing Record 29 of Set 9 | ugoofaaru
# Processing Record 30 of Set 9 | taoudenni
# Processing Record 31 of Set 9 | wellington
# Processing Record 32 of Set 9 | north bend
# Processing Record 33 of Set 9 | avera
# Processing Record 34 of Set 9 | maheshwar
# Processing Record 35 of Set 9 | diamantino
# Processing Record 36 of Set 9 | bajo baudo
# City not found. Skipping...
# Processing Record 38 of Set 9 | bom jesus
# Processing Record 39 of Set 9 | tongling
# Processing Record 40 of Set 9 | santa cruz cabralia
# Processing Record 41 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 43 of Set 9 | guerrero negro
# Processing Record 44 of Set 9 | bafq
# Processing Record 45 of Set 9 | cabedelo
# Processing Record 46 of Set 9 | ginda
# Processing Record 47 of Set 9 | belaya gora
# Processing Record 48 of Set 9 | ust-kuyga
# Processing Record 49 of Set 9 | zhezkazgan
# Processing Record 50 of Set 9 | erzin
# Processing Record 1 of Set 10 | nkan
# Processing Record 2 of Set 10 | juneau
# Processing Record 3 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 5 of Set 10 | dudinka
# Processing Record 6 of Set 10 | paita
# Processing Record 7 of Set 10 | tete
# Processing Record 8 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 10 | maracacume
# Processing Record 11 of Set 10 | talawdi
# City not found. Skipping...
# Processing Record 13 of Set 10 | novosheshminsk
# Processing Record 14 of Set 10 | kampot
# Processing Record 15 of Set 10 | sal rei
# Processing Record 16 of Set 10 | conde
# Processing Record 17 of Set 10 | tra vinh
# Processing Record 18 of Set 10 | manali
# Processing Record 19 of Set 10 | shaoguan
# Processing Record 20 of Set 10 | dunedin
# Processing Record 21 of Set 10 | kahului
# Processing Record 22 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 10 | asfi
# Processing Record 25 of Set 10 | kulykiv
# Processing Record 26 of Set 10 | jawhar
# Processing Record 27 of Set 10 | svetlyy
# Processing Record 28 of Set 10 | arman
# Processing Record 29 of Set 10 | patea
# Processing Record 30 of Set 10 | baherden
# Processing Record 31 of Set 10 | sept-iles
# Processing Record 32 of Set 10 | dryden
# Processing Record 33 of Set 10 | naranjal
# Processing Record 34 of Set 10 | itarema
# Processing Record 35 of Set 10 | pacific grove
# Processing Record 36 of Set 10 | lompoc
# Processing Record 37 of Set 10 | cheyenne
# Processing Record 38 of Set 10 | balabac
# Processing Record 39 of Set 10 | cockburn town
# Processing Record 40 of Set 10 | novovasylivka
# Processing Record 41 of Set 10 | basco
# Processing Record 42 of Set 10 | pathein
# Processing Record 43 of Set 10 | uusikaupunki
# Processing Record 44 of Set 10 | balkanabat
# Processing Record 45 of Set 10 | shubarshi
# Processing Record 46 of Set 10 | bilma
# Processing Record 47 of Set 10 | maningrida
# Processing Record 48 of Set 10 | newport
# Processing Record 49 of Set 10 | yeppoon
# Processing Record 50 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 1 of Set 11 | conceicao do castelo
# Processing Record 2 of Set 11 | kabankalan
# Processing Record 3 of Set 11 | dibaya
# City not found. Skipping...
# Processing Record 5 of Set 11 | sisimiut
# Processing Record 6 of Set 11 | minas novas
# Processing Record 7 of Set 11 | aleksandriya
# Processing Record 8 of Set 11 | kieta
# Processing Record 9 of Set 11 | solone
# Processing Record 10 of Set 11 | barvinkove
# Processing Record 11 of Set 11 | steinkjer
# Processing Record 12 of Set 11 | kaeo
# Processing Record 13 of Set 11 | iwanai
# Processing Record 14 of Set 11 | dali
# Processing Record 15 of Set 11 | sompeta
# Processing Record 16 of Set 11 | lavras
# Processing Record 17 of Set 11 | tuy hoa
# Processing Record 18 of Set 11 | tadine
# Processing Record 19 of Set 11 | skibbereen
# Processing Record 20 of Set 11 | barajevo
# Processing Record 21 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 11 | grindavik
# Processing Record 24 of Set 11 | mackay
# Processing Record 25 of Set 11 | jaroslaw
# Processing Record 26 of Set 11 | tessalit
# Processing Record 27 of Set 11 | ilhabela
# Processing Record 28 of Set 11 | maragogi
# Processing Record 29 of Set 11 | warrington
# Processing Record 30 of Set 11 | porvoo
# Processing Record 31 of Set 11 | burhaniye
# Processing Record 32 of Set 11 | kyzyl-suu
# Processing Record 33 of Set 11 | talnakh
# Processing Record 34 of Set 11 | henties bay
# Processing Record 35 of Set 11 | hay river
# Processing Record 36 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 11 | deputatskiy
# Processing Record 39 of Set 11 | talara
# Processing Record 40 of Set 11 | araouane
# Processing Record 41 of Set 11 | matara
# Processing Record 42 of Set 11 | port macquarie
# Processing Record 43 of Set 11 | ulladulla
# Processing Record 44 of Set 11 | rolleston
# Processing Record 45 of Set 11 | sioux lookout
# Processing Record 46 of Set 11 | jalu
# Processing Record 47 of Set 11 | waipawa
# Processing Record 48 of Set 11 | requena
# Processing Record 49 of Set 11 | maceio
# Processing Record 50 of Set 11 | akyab
# Processing Record 1 of Set 12 | garoua
# Processing Record 2 of Set 12 | shieli
# Processing Record 3 of Set 12 | westport
# Processing Record 4 of Set 12 | santa cruz
# Processing Record 5 of Set 12 | shubarkuduk
# Processing Record 6 of Set 12 | ikongo
# Processing Record 7 of Set 12 | voloshka
# Processing Record 8 of Set 12 | ajdabiya
# Processing Record 9 of Set 12 | balaipungut
# Processing Record 10 of Set 12 | taksimo
# Processing Record 11 of Set 12 | matsuura
# Processing Record 12 of Set 12 | puerto suarez
# Processing Record 13 of Set 12 | chemainus
# Processing Record 14 of Set 12 | arlit
# Processing Record 15 of Set 12 | canton
# Processing Record 16 of Set 12 | sunyani
# Processing Record 17 of Set 12 | roma
# Processing Record 18 of Set 12 | tuktoyaktuk
# Processing Record 19 of Set 12 | zenzeli
# Processing Record 20 of Set 12 | liverpool
# Processing Record 21 of Set 12 | eyrarbakki
# Processing Record 22 of Set 12 | mogoytuy
# Processing Record 23 of Set 12 | eureka
# Processing Record 24 of Set 12 | arrifes
# Processing Record 25 of Set 12 | kharp
# Processing Record 26 of Set 12 | hofn
# Processing Record 27 of Set 12 | marion
# Processing Record 28 of Set 12 | poltavka
# Processing Record 29 of Set 12 | maturin
# Processing Record 30 of Set 12 | pinellas park
# Processing Record 31 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 12 | bitung
# Processing Record 34 of Set 12 | mackenzie
# Processing Record 35 of Set 12 | constitucion
# Processing Record 36 of Set 12 | gornopravdinsk
# Processing Record 37 of Set 12 | cookeville
# Processing Record 38 of Set 12 | vestmannaeyjar
# Processing Record 39 of Set 12 | luwingu
# Processing Record 40 of Set 12 | teguise
# Processing Record 41 of Set 12 | calama
# Processing Record 42 of Set 12 | kumla
# Processing Record 43 of Set 12 | moquegua
# Processing Record 44 of Set 12 | kiama
# Processing Record 45 of Set 12 | nantucket
# Processing Record 46 of Set 12 | canutama
# Processing Record 47 of Set 12 | channel-port aux basques
# Processing Record 48 of Set 12 | kloulklubed
# Processing Record 49 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 1 of Set 13 | farah
# Processing Record 2 of Set 13 | kruisfontein
# Processing Record 3 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 13 | san patricio
# Processing Record 6 of Set 13 | sitka
# Processing Record 7 of Set 13 | hobyo
# Processing Record 8 of Set 13 | general roca
# Processing Record 9 of Set 13 | la suiza
# Processing Record 10 of Set 13 | manutuke
# Processing Record 11 of Set 13 | normandin
# Processing Record 12 of Set 13 | porto santo
# Processing Record 13 of Set 13 | la ronge
# Processing Record 14 of Set 13 | yankton
# Processing Record 15 of Set 13 | walvis bay
# Processing Record 16 of Set 13 | victor harbor
# Processing Record 17 of Set 13 | hualmay
# Processing Record 18 of Set 13 | riviere-au-renard
# Processing Record 19 of Set 13 | sabha
# Processing Record 20 of Set 13 | asvanyraro
# Processing Record 21 of Set 13 | aktash
# Processing Record 22 of Set 13 | savinka
# Processing Record 23 of Set 13 | sosnovo-ozerskoye
# Processing Record 24 of Set 13 | sivaki
# Processing Record 25 of Set 13 | muyezerskiy
# Processing Record 26 of Set 13 | altay
# Processing Record 27 of Set 13 | crixas
# Processing Record 28 of Set 13 | turukhansk
# Processing Record 29 of Set 13 | davila
# Processing Record 30 of Set 13 | iqaluit
# Processing Record 31 of Set 13 | orlik
# Processing Record 32 of Set 13 | santana do matos
# Processing Record 33 of Set 13 | yushan
# Processing Record 34 of Set 13 | simnicu de sus
# Processing Record 35 of Set 13 | ahtopol
# Processing Record 36 of Set 13 | tilichiki
# Processing Record 37 of Set 13 | maryborough
# Processing Record 38 of Set 13 | chiredzi
# Processing Record 39 of Set 13 | namibe
# Processing Record 40 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 13 | noyabrsk
# Processing Record 43 of Set 13 | port hardy
# Processing Record 44 of Set 13 | coihaique
# Processing Record 45 of Set 13 | mingaora
# Processing Record 46 of Set 13 | innisfail
# Processing Record 47 of Set 13 | nizhniy tsasuchey
# Processing Record 48 of Set 13 | hovd
# Processing Record 49 of Set 13 | san andres
# Processing Record 50 of Set 13 | chimore
# Processing Record 1 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 3 of Set 14 | arauco
# Processing Record 4 of Set 14 | nome
# Processing Record 5 of Set 14 | maridi
# Processing Record 6 of Set 14 | mount isa
# Processing Record 7 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 9 of Set 14 | liuzhou
# Processing Record 10 of Set 14 | obo
# Processing Record 11 of Set 14 | chupa
# Processing Record 12 of Set 14 | benguela
# Processing Record 13 of Set 14 | del rio
# Processing Record 14 of Set 14 | nampula
# Processing Record 15 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 14 | pinotepa de don luis
# Processing Record 18 of Set 14 | labuhan
# Processing Record 19 of Set 14 | sabang
# Processing Record 20 of Set 14 | rawson
# Processing Record 21 of Set 14 | san francisco
# Processing Record 22 of Set 14 | kroya
# Processing Record 23 of Set 14 | muroto
# Processing Record 24 of Set 14 | cooma
# Processing Record 25 of Set 14 | riachao das neves
# Processing Record 26 of Set 14 | gat
# Processing Record 27 of Set 14 | urucara
# Processing Record 28 of Set 14 | kibungo
# Processing Record 29 of Set 14 | young
# Processing Record 30 of Set 14 | sobolevo
# Processing Record 31 of Set 14 | sergeyevka
# Processing Record 32 of Set 14 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 14 | balimo
# City not found. Skipping...
# Processing Record 38 of Set 14 | carauari
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert data to DataFrame
weather_df = pd.DataFrame({"City": city_final,
                          "Lat": lat,
                          "Lng": long,
                          "Max Temp": maxtemp,
                          "Humidity": humidity,
                          "Cloudiness": cloudiness,
                          "Wind Speed": wind,
                          "Country": country,
                          "Date": date})

# Format latitude/longitude for two decimal places only, retain as float
weather_df['Lat'] = weather_df['Lat'].map('{:.2f}'.format).astype(float)
weather_df['Lng'] = weather_df['Lng'].map('{:.2f}'.format).astype(float)

# Export to CSV
weather_df.to_csv(output_data_file, index=False, header=True)

# Display the DataFrame
weather_df.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Cervo  43.67   -7.41     57.96        85          71        9.15
# 1       Ushuaia -54.80  -68.30     46.06        61          40        8.05
# 2     Tuatapere -46.13  167.68     46.22        88           2        6.98
# 3  Punta Arenas -53.15  -70.92     50.11        53           0       11.50
# 4  Longyearbyen  78.22   15.64     12.04        52          57       27.63
#
#   Country        Date
# 0      ES  1649570129
# 1      AR  1649589259
# 2      NZ  1649618372
# 3      CL  1649589738
# 4      SJ  1649555299

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Describe the DataFrame
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  588.000000  588.000000  588.000000  588.000000  588.000000  588.000000
# mean    20.739405   16.870391   59.221190   71.112245   55.600340    8.990697
# std     32.693465   91.310146   24.057036   22.643921   39.740664    6.082032
# min    -54.800000 -175.200000  -21.230000    1.000000    0.000000    0.000000
# 25%     -6.145000  -63.915000   43.875000   58.000000   12.750000    4.380000
# 50%     25.330000   20.920000   64.390000   77.000000   63.500000    7.805000
# 75%     47.840000   99.917500   78.142500   88.000000   99.000000   12.000000
# max     78.220000  179.320000   98.550000  100.000000  100.000000   40.290000
#
#                Date
# count  5.880000e+02
# mean   1.649598e+09
# std    2.768481e+04
# min    1.649555e+09
# 25%    1.649574e+09
# 50%    1.649593e+09
# 75%    1.649625e+09
# max    1.649699e+09

# %%
# Get the indices of cities that have humidity over 100%.
excess_humidity = weather_df.loc[weather_df['Humidity'] > 100].index
excess_humidity
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_df.drop(excess_humidity, inplace=False)
clean_city_data.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Cervo  43.67   -7.41     57.96        85          71        9.15
# 1       Ushuaia -54.80  -68.30     46.06        61          40        8.05
# 2     Tuatapere -46.13  167.68     46.22        88           2        6.98
# 3  Punta Arenas -53.15  -70.92     50.11        53           0       11.50
# 4  Longyearbyen  78.22   15.64     12.04        52          57       27.63
#
#   Country        Date
# 0      ES  1649570129
# 1      AR  1649589259
# 2      NZ  1649618372
# 3      CL  1649589738
# 4      SJ  1649555299

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs in the output_data folder
# * Below are examples of what you should get but your results will be different.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Convert Date column to datetime for date display
clean_city_data['Date'] = clean_city_data['Date'].astype("datetime64[s]")
# Obtain the oldest date in our dataset to reflect dataset's age and apply formatting
display_date = clean_city_data['Date'].min().strftime('%m/%d/%y')

# Plot Latitude vs. Temperature with title, labels, and grid
plt.scatter(clean_city_data['Lat'], clean_city_data['Max Temp'], marker="o", facecolors="C0", edgecolors="black")
plt.title(f"City Latitude vs. Max Temperature ({display_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("Images/Lat_v_Temp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Plot Latitude vs. Humidity with title, labels, and grid
plt.scatter(clean_city_data['Lat'], clean_city_data['Humidity'], marker="o", facecolors="C0", edgecolors="black")
plt.title(f"City Latitude vs. Humidity ({display_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("Images/Lat_v_Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Plot Latitude vs. Cloudiness with title, labels, and grid
plt.scatter(clean_city_data['Lat'], clean_city_data['Cloudiness'], marker="o", facecolors="C0", edgecolors="black")
plt.title(f"City Latitude vs. Cloudiness ({display_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("Images/Lat_v_Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Plot Latitude vs. Wind Speed with title, labels, and grid
plt.scatter(clean_city_data['Lat'], clean_city_data['Wind Speed'], marker="o", facecolors="C0", edgecolors="black")
plt.title(f"City Latitude vs. Wind Speed ({display_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("Images/Lat_v_Wind_Speed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create separate DataFrames for northern and southern hemispheres
clean_city_data_north = pd.DataFrame(clean_city_data.loc[clean_city_data['Lat']>=0])
clean_city_data_south = pd.DataFrame(clean_city_data.loc[clean_city_data['Lat']<0])

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Calculate linear regression for Northern Hemisphere Latitude vs. Max Temperature
(slope, intercept, rvalue, pvalue, stderr) = linregress(clean_city_data_north['Lat'], clean_city_data_north['Max Temp'])
regress_values = clean_city_data_north['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot Northern Hemisphere Latitude vs. Max Temperature with linear regression, labels
plt.scatter(clean_city_data_north['Lat'], clean_city_data_north['Max Temp'], marker="o")

plt.plot(clean_city_data_north['Lat'],regress_values,"r-")
plt.annotate(line_eq,(10,5),fontsize=15,color="red")

plt.title(f"Northern Hemisphere: \n City Latitude vs. Max Temperature ({display_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

print(f"The r-value is: {rvalue**2}")
plt.savefig("Images/Lat_v_Temp_North.png")
plt.show()
# Out:
# The r-value is: 0.7715311039180107

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Calculate linear regression for Southern Hemisphere Latitude vs. Max Temperature
(slope, intercept, rvalue, pvalue, stderr) = linregress(clean_city_data_south['Lat'], clean_city_data_south['Max Temp'])
regress_values = clean_city_data_south['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot Southern Hemisphere Latitude vs. Max Temperature with linear regression, labels
plt.scatter(clean_city_data_south['Lat'], clean_city_data_south['Max Temp'], marker="o")

plt.plot(clean_city_data_south['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-25,45),fontsize=15,color="red")

plt.title(f"Southern Hemisphere: \n City Latitude vs. Max Temperature ({display_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

print(f"The r-value is: {rvalue**2}")
plt.savefig("Images/Lat_v_Temp_South.png")
plt.show()
# Out:
# The r-value is: 0.5859648366851511

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Calculate linear regression for Northern Hemisphere Latitude vs. Humidity
(slope, intercept, rvalue, pvalue, stderr) = linregress(clean_city_data_north['Lat'], clean_city_data_north['Humidity'])
regress_values = clean_city_data_north['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot Northern Hemisphere Latitude vs. Humidity with linear regression, labels
plt.scatter(clean_city_data_north['Lat'], clean_city_data_north['Humidity'], marker="o")

plt.plot(clean_city_data_north['Lat'],regress_values,"r-")
plt.annotate(line_eq,(45,0.8),fontsize=15,color="red")

plt.title(f"Northern Hemisphere: \n City Latitude vs. Humidity (%) ({display_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

print(f"The r-value is: {rvalue**2}")
plt.savefig("Images/Lat_v_Humidity_North.png")
plt.show()
# Out:
# The r-value is: 0.05919225293696865

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Calculate linear regression for Southern Hemisphere Latitude vs. Humidity
(slope, intercept, rvalue, pvalue, stderr) = linregress(clean_city_data_south['Lat'], clean_city_data_south['Humidity'])
regress_values = clean_city_data_south['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot Southern Hemisphere Latitude vs. Humidity with linear regression, labels
plt.scatter(clean_city_data_south['Lat'], clean_city_data_south['Humidity'], marker="o")

plt.plot(clean_city_data_south['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")

plt.title(f"Southern Hemisphere: \n City Latitude vs. Humidity (%) ({display_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

print(f"The r-value is: {rvalue**2}")
plt.savefig("Images/Lat_v_Humidity_South.png")
plt.show()
# Out:
# The r-value is: 3.7575819300804954e-06

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Calculate linear regression for Northern Hemisphere Latitude vs. Cloudiness
(slope, intercept, rvalue, pvalue, stderr) = linregress(clean_city_data_north['Lat'], clean_city_data_north['Cloudiness'])
regress_values = clean_city_data_north['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot Northern Hemisphere Latitude vs. Cloudiness with linear regression, labels
plt.scatter(clean_city_data_north['Lat'], clean_city_data_north['Cloudiness'], marker="o")

plt.plot(clean_city_data_north['Lat'],regress_values,"r-")
plt.annotate(line_eq,(5.8,10),fontsize=15,color="red")

plt.title(f"Northern Hemisphere: \n City Latitude vs. Cloudiness (%) ({display_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

print(f"The r-value is: {rvalue**2}")
plt.savefig("Images/Lat_v_Cloudiness_North.png")
plt.show()
# Out:
# The r-value is: 0.061051911880940654

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Calculate linear regression for Southern Hemisphere Latitude vs. Cloudiness
(slope, intercept, rvalue, pvalue, stderr) = linregress(clean_city_data_south['Lat'], clean_city_data_south['Cloudiness'])
regress_values = clean_city_data_south['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot Southern Hemisphere Latitude vs. Cloudiness with linear regression, labels
plt.scatter(clean_city_data_south['Lat'], clean_city_data_south['Cloudiness'], marker="o")

plt.plot(clean_city_data_south['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-25,10),fontsize=15,color="red")

plt.title(f"Southern Hemisphere: \n City Latitude vs. Cloudiness (%) ({display_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

print(f"The r-value is: {rvalue**2}")
plt.savefig("Images/Lat_v_Cloudiness_South.png")
plt.show()
# Out:
# The r-value is: 0.04518761235772653

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Calculate linear regression for Northern Hemisphere Latitude vs. Wind Speed
(slope, intercept, rvalue, pvalue, stderr) = linregress(clean_city_data_north['Lat'], clean_city_data_north['Wind Speed'])
regress_values = clean_city_data_north['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot Northern Hemisphere Latitude vs. Wind Speed with linear regression, labels
plt.scatter(clean_city_data_north['Lat'], clean_city_data_north['Wind Speed'], marker="o")

plt.plot(clean_city_data_north['Lat'],regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

plt.title(f"Northern Hemisphere: \n City Latitude vs. Wind Speed (mph) ({display_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

print(f"The r-value is: {rvalue**2}")
plt.savefig("Images/Lat_v_Wind_Speed_North.png")
plt.show()
# Out:
# The r-value is: 0.0008121314595324208

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Calculate linear regression for Southern Hemisphere Latitude vs. Wind Speed
(slope, intercept, rvalue, pvalue, stderr) = linregress(clean_city_data_south['Lat'], clean_city_data_south['Wind Speed'])
regress_values = clean_city_data_south['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot Southern Hemisphere Latitude vs. Wind Speed with linear regression, labels
plt.scatter(clean_city_data_south['Lat'], clean_city_data_south['Wind Speed'], marker="o")

plt.plot(clean_city_data_south['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-45,3),fontsize=15,color="red")

plt.title(f"Southern Hemisphere: \n City Latitude vs. Wind Speed (mph) ({display_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

print(f"The r-value is: {rvalue**2}")
plt.savefig("Images/Lat_v_Wind_Speed_South.png")
plt.show()
# Out:
# The r-value is: 0.02640828889867352
